# %% [markdown]
# # Fetcher
#
# The Fetcher class builds on the unified data request interfaces to provide convenient methods for working with whole datasets. Specifically, you can:
#
# 1. Get continuous data using channels contained in an inventory (or returned from a station_client).
#
#
# 2. Iterate over events and their corresponding waveforms, which have channels defined by the station_client.
#
# Additional methods are possible and may be implemented in the future.
#
# ## Setup
# We will use a Fetcher from the TA and Crandall dataset to demonstrate different aspects of the `Fetcher` functionality.

# %%
import obsplus

# ta_test dataset contains continuous data
ta_dataset = obsplus.load_dataset('ta_test')
crandall = obsplus.load_dataset('crandall_test')

# crandall contains only event data
ta_fetcher = ta_dataset.get_fetcher()
crandall_fetcher = crandall.get_fetcher()
# Out:
# downloading waveform data for ta_test dataset ...
# finished downloading waveform data for ta_test
# downloading station data for ta_test dataset ...
# finished downloading station data for ta_test
# downloading event data for ta_test dataset ...
# finished downloading event data for ta_test
# downloading waveform data for crandall_test dataset ...
# [2020-07-27 14:47:25,991] - obspy.clients.fdsn.mass_downloader - INFO: Initializing FDSN client(s) for http://service.iris.edu.
# [2020-07-27 14:47:25,993] - obspy.clients.fdsn.mass_downloader - INFO: Successfully initialized 1 client(s): http://service.iris.edu.
# [2020-07-27 14:47:25,994] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 0
# [2020-07-27 14:47:25,995] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Requesting reliable availability.
# [2020-07-27 14:47:28,446] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully requested availability (2.45 seconds)
# [2020-07-27 14:47:28,490] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Found 19 stations (57 channels).
# [2020-07-27 14:47:28,495] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Will attempt to download data from 19 stations.
# [2020-07-27 14:47:28,498] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 57 time intervals/channels before downloading: NEEDS_DOWNLOADING
# [2020-07-27 14:47:29,612] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded 7 channels (of 7)
# [2020-07-27 14:47:31,359] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded 41 channels (of 50)
# [2020-07-27 14:47:31,361] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Launching basic QC checks...
# [2020-07-27 14:47:31,418] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Downloaded 0.4 MB [154.50 KB/sec] of data, 0.0 MB of which were discarded afterwards.
# [2020-07-27 14:47:31,419] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 9 time intervals/channels after downloading: DOWNLOAD_FAILED
# [2020-07-27 14:47:31,420] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 48 time intervals/channels after downloading: DOWNLOADED
# [2020-07-27 14:47:31,566] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded '/home/runner/opsdata/crandall_test/stations/TA.O15A.xml'.
# [2020-07-27 14:47:31,570] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded '/home/runner/opsdata/crandall_test/stations/TA.O18A.xml'.
# [2020-07-27 14:47:31,571] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded '/home/runner/opsdata/crandall_test/stations/TA.P16A.xml'.
# [2020-07-27 14:47:31,712] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded '/home/runner/opsdata/crandall_test/stations/TA.O16A.xml'.
# [2020-07-27 14:47:31,716] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded '/home/runner/opsdata/crandall_test/stations/TA.P15A.xml'.
# [2020-07-27 14:47:31,718] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded '/home/runner/opsdata/crandall_test/stations/TA.P17A.xml'.
# [2020-07-27 14:47:31,857] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded '/home/runner/opsdata/crandall_test/stations/TA.R17A.xml'.
# [2020-07-27 14:47:31,861] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded '/home/runner/opsdata/crandall_test/stations/TA.Q16A.xml'.
# [2020-07-27 14:47:31,864] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded '/home/runner/opsdata/crandall_test/stations/TA.P18A.xml'.
# [2020-07-27 14:47:31,998] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded '/home/runner/opsdata/crandall_test/stations/UU.CTU.xml'.
# [2020-07-27 14:47:32,009] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded '/home/runner/opsdata/crandall_test/stations/TA.Q15A.xml'.
# [2020-07-27 14:47:32,009] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded '/home/runner/opsdata/crandall_test/stations/TA.Q18A.xml'.
# [2020-07-27 14:47:32,140] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded '/home/runner/opsdata/crandall_test/stations/UU.MPU.xml'.
# [2020-07-27 14:47:32,166] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded '/home/runner/opsdata/crandall_test/stations/UU.SRU.xml'.
# [2020-07-27 14:47:32,278] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded '/home/runner/opsdata/crandall_test/stations/UU.NLU.xml'.
# [2020-07-27 14:47:32,307] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded '/home/runner/opsdata/crandall_test/stations/UU.TMU.xml'.
# [2020-07-27 14:47:32,326] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Downloaded 16 station files [0.4 MB] in 0.9 seconds [482.00 KB/sec].
# [2020-07-27 14:47:32,327] - obspy.clients.fdsn.mass_downloader - INFO: ============================== Final report
# [2020-07-27 14:47:32,328] - obspy.clients.fdsn.mass_downloader - INFO: 0 MiniSEED files [0.0 MB] already existed.
# [2020-07-27 14:47:32,328] - obspy.clients.fdsn.mass_downloader - INFO: 0 StationXML files [0.0 MB] already existed.
# [2020-07-27 14:47:32,330] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 48 MiniSEED files [0.4 MB].
# [2020-07-27 14:47:32,330] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 16 StationXML files [0.4 MB].
# [2020-07-27 14:47:32,331] - obspy.clients.fdsn.mass_downloader - INFO: Downloaded 0.8 MB in total.
# [2020-07-27 14:47:32,479] - obspy.clients.fdsn.mass_downloader - INFO: Initializing FDSN client(s) for http://service.iris.edu.
# [2020-07-27 14:47:32,481] - obspy.clients.fdsn.mass_downloader - INFO: Successfully initialized 1 client(s): http://service.iris.edu.
# [2020-07-27 14:47:32,482] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 0
# [2020-07-27 14:47:32,482] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Requesting reliable availability.
# [2020-07-27 14:47:34,561] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully requested availability (2.08 seconds)
# [2020-07-27 14:47:34,605] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Found 19 stations (57 channels).
# [2020-07-27 14:47:34,611] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Will attempt to download data from 19 stations.
# [2020-07-27 14:47:34,614] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 57 time intervals/channels before downloading: NEEDS_DOWNLOADING
# [2020-07-27 14:47:35,821] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded 7 channels (of 7)
# [2020-07-27 14:47:37,269] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded 44 channels (of 50)
# [2020-07-27 14:47:37,270] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Launching basic QC checks...
# [2020-07-27 14:47:37,313] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Downloaded 0.3 MB [113.18 KB/sec] of data, 0.0 MB of which were discarded afterwards.
# [2020-07-27 14:47:37,314] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 6 time intervals/channels after downloading: DOWNLOAD_FAILED
# [2020-07-27 14:47:37,315] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 51 time intervals/channels after downloading: DOWNLOADED
# [2020-07-27 14:47:37,478] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded '/home/runner/opsdata/crandall_test/stations/TA.R16A.xml'.
# [2020-07-27 14:47:37,482] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Downloaded 1 station files [0.0 MB] in 0.1 seconds [158.61 KB/sec].
# [2020-07-27 14:47:37,483] - obspy.clients.fdsn.mass_downloader - INFO: ============================== Final report
# [2020-07-27 14:47:37,484] - obspy.clients.fdsn.mass_downloader - INFO: 0 MiniSEED files [0.0 MB] already existed.
# [2020-07-27 14:47:37,485] - obspy.clients.fdsn.mass_downloader - INFO: 16 StationXML files [0.4 MB] already existed.
# [2020-07-27 14:47:37,487] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 51 MiniSEED files [0.3 MB].
# [2020-07-27 14:47:37,488] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 1 StationXML files [0.0 MB].
# [2020-07-27 14:47:37,489] - obspy.clients.fdsn.mass_downloader - INFO: Downloaded 0.3 MB in total.
# [2020-07-27 14:47:37,626] - obspy.clients.fdsn.mass_downloader - INFO: Initializing FDSN client(s) for http://service.iris.edu.
# [2020-07-27 14:47:37,628] - obspy.clients.fdsn.mass_downloader - INFO: Successfully initialized 1 client(s): http://service.iris.edu.
# [2020-07-27 14:47:37,628] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 0
# [2020-07-27 14:47:37,629] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Requesting reliable availability.
# [2020-07-27 14:47:40,195] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully requested availability (2.57 seconds)
# [2020-07-27 14:47:40,239] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Found 19 stations (57 channels).
# [2020-07-27 14:47:40,244] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Will attempt to download data from 19 stations.
# [2020-07-27 14:47:40,246] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 57 time intervals/channels before downloading: NEEDS_DOWNLOADING
# [2020-07-27 14:47:41,247] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded 7 channels (of 7)
# [2020-07-27 14:47:41,289] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded 44 channels (of 50)
# [2020-07-27 14:47:41,291] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Launching basic QC checks...
# [2020-07-27 14:47:41,339] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Downloaded 0.3 MB [303.88 KB/sec] of data, 0.0 MB of which were discarded afterwards.
# [2020-07-27 14:47:41,340] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 6 time intervals/channels after downloading: DOWNLOAD_FAILED
# [2020-07-27 14:47:41,341] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 51 time intervals/channels after downloading: DOWNLOADED
# [2020-07-27 14:47:41,361] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - No station information to download.
# [2020-07-27 14:47:41,362] - obspy.clients.fdsn.mass_downloader - INFO: ============================== Final report
# [2020-07-27 14:47:41,363] - obspy.clients.fdsn.mass_downloader - INFO: 0 MiniSEED files [0.0 MB] already existed.
# [2020-07-27 14:47:41,363] - obspy.clients.fdsn.mass_downloader - INFO: 17 StationXML files [0.4 MB] already existed.
# [2020-07-27 14:47:41,365] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 51 MiniSEED files [0.3 MB].
# [2020-07-27 14:47:41,365] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 0 StationXML files [0.0 MB].
# [2020-07-27 14:47:41,366] - obspy.clients.fdsn.mass_downloader - INFO: Downloaded 0.3 MB in total.
# [2020-07-27 14:47:41,510] - obspy.clients.fdsn.mass_downloader - INFO: Initializing FDSN client(s) for http://service.iris.edu.
# [2020-07-27 14:47:41,512] - obspy.clients.fdsn.mass_downloader - INFO: Successfully initialized 1 client(s): http://service.iris.edu.
# [2020-07-27 14:47:41,513] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 0
# [2020-07-27 14:47:41,513] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Requesting reliable availability.
# [2020-07-27 14:47:43,186] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully requested availability (1.67 seconds)
# [2020-07-27 14:47:43,234] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Found 19 stations (57 channels).
# [2020-07-27 14:47:43,240] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Will attempt to download data from 19 stations.
# [2020-07-27 14:47:43,243] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 57 time intervals/channels before downloading: NEEDS_DOWNLOADING
# [2020-07-27 14:47:44,269] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded 44 channels (of 50)
# [2020-07-27 14:47:44,340] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded 7 channels (of 7)
# [2020-07-27 14:47:44,342] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Launching basic QC checks...
# [2020-07-27 14:47:44,391] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Downloaded 0.3 MB [291.51 KB/sec] of data, 0.0 MB of which were discarded afterwards.
# [2020-07-27 14:47:44,392] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 6 time intervals/channels after downloading: DOWNLOAD_FAILED
# [2020-07-27 14:47:44,392] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 51 time intervals/channels after downloading: DOWNLOADED
# [2020-07-27 14:47:44,412] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - No station information to download.
# [2020-07-27 14:47:44,412] - obspy.clients.fdsn.mass_downloader - INFO: ============================== Final report
# [2020-07-27 14:47:44,413] - obspy.clients.fdsn.mass_downloader - INFO: 0 MiniSEED files [0.0 MB] already existed.
# [2020-07-27 14:47:44,413] - obspy.clients.fdsn.mass_downloader - INFO: 17 StationXML files [0.4 MB] already existed.
# [2020-07-27 14:47:44,414] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 51 MiniSEED files [0.3 MB].
# [2020-07-27 14:47:44,415] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 0 StationXML files [0.0 MB].
# [2020-07-27 14:47:44,415] - obspy.clients.fdsn.mass_downloader - INFO: Downloaded 0.3 MB in total.
# [2020-07-27 14:47:44,563] - obspy.clients.fdsn.mass_downloader - INFO: Initializing FDSN client(s) for http://service.iris.edu.
# [2020-07-27 14:47:44,564] - obspy.clients.fdsn.mass_downloader - INFO: Successfully initialized 1 client(s): http://service.iris.edu.
# [2020-07-27 14:47:44,565] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 0
# [2020-07-27 14:47:44,565] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Requesting reliable availability.
# [2020-07-27 14:47:46,416] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully requested availability (1.85 seconds)
# [2020-07-27 14:47:46,459] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Found 19 stations (57 channels).
# [2020-07-27 14:47:46,464] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Will attempt to download data from 19 stations.
# [2020-07-27 14:47:46,467] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 57 time intervals/channels before downloading: NEEDS_DOWNLOADING
# [2020-07-27 14:47:47,187] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded 7 channels (of 7)
# [2020-07-27 14:47:47,516] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded 44 channels (of 50)
# [2020-07-27 14:47:47,517] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Launching basic QC checks...
# [2020-07-27 14:47:47,561] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Downloaded 0.3 MB [310.52 KB/sec] of data, 0.0 MB of which were discarded afterwards.
# [2020-07-27 14:47:47,562] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 6 time intervals/channels after downloading: DOWNLOAD_FAILED
# [2020-07-27 14:47:47,563] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 51 time intervals/channels after downloading: DOWNLOADED
# [2020-07-27 14:47:47,583] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - No station information to download.
# [2020-07-27 14:47:47,584] - obspy.clients.fdsn.mass_downloader - INFO: ============================== Final report
# [2020-07-27 14:47:47,584] - obspy.clients.fdsn.mass_downloader - INFO: 0 MiniSEED files [0.0 MB] already existed.
# [2020-07-27 14:47:47,585] - obspy.clients.fdsn.mass_downloader - INFO: 17 StationXML files [0.4 MB] already existed.
# [2020-07-27 14:47:47,586] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 51 MiniSEED files [0.3 MB].
# [2020-07-27 14:47:47,586] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 0 StationXML files [0.0 MB].
# [2020-07-27 14:47:47,586] - obspy.clients.fdsn.mass_downloader - INFO: Downloaded 0.3 MB in total.
# [2020-07-27 14:47:47,719] - obspy.clients.fdsn.mass_downloader - INFO: Initializing FDSN client(s) for http://service.iris.edu.
# [2020-07-27 14:47:47,721] - obspy.clients.fdsn.mass_downloader - INFO: Successfully initialized 1 client(s): http://service.iris.edu.
# [2020-07-27 14:47:47,722] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 0
# [2020-07-27 14:47:47,723] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Requesting reliable availability.
# [2020-07-27 14:47:49,631] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully requested availability (1.91 seconds)
# [2020-07-27 14:47:49,675] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Found 19 stations (57 channels).
# [2020-07-27 14:47:49,680] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Will attempt to download data from 19 stations.
# [2020-07-27 14:47:49,683] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 57 time intervals/channels before downloading: NEEDS_DOWNLOADING
# [2020-07-27 14:47:50,373] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded 7 channels (of 7)
# [2020-07-27 14:47:50,775] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded 41 channels (of 50)
# [2020-07-27 14:47:50,776] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Launching basic QC checks...
# [2020-07-27 14:47:50,821] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Downloaded 0.3 MB [261.94 KB/sec] of data, 0.0 MB of which were discarded afterwards.
# [2020-07-27 14:47:50,822] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 9 time intervals/channels after downloading: DOWNLOAD_FAILED
# [2020-07-27 14:47:50,823] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 48 time intervals/channels after downloading: DOWNLOADED
# [2020-07-27 14:47:50,841] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - No station information to download.
# [2020-07-27 14:47:50,842] - obspy.clients.fdsn.mass_downloader - INFO: ============================== Final report
# [2020-07-27 14:47:50,843] - obspy.clients.fdsn.mass_downloader - INFO: 0 MiniSEED files [0.0 MB] already existed.
# [2020-07-27 14:47:50,844] - obspy.clients.fdsn.mass_downloader - INFO: 16 StationXML files [0.4 MB] already existed.
# [2020-07-27 14:47:50,845] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 48 MiniSEED files [0.3 MB].
# [2020-07-27 14:47:50,845] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 0 StationXML files [0.0 MB].
# [2020-07-27 14:47:50,846] - obspy.clients.fdsn.mass_downloader - INFO: Downloaded 0.3 MB in total.
# [2020-07-27 14:47:50,993] - obspy.clients.fdsn.mass_downloader - INFO: Initializing FDSN client(s) for http://service.iris.edu.
# [2020-07-27 14:47:50,995] - obspy.clients.fdsn.mass_downloader - INFO: Successfully initialized 1 client(s): http://service.iris.edu.
# [2020-07-27 14:47:50,995] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 0
# [2020-07-27 14:47:50,996] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Requesting reliable availability.
# [2020-07-27 14:47:53,276] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully requested availability (2.28 seconds)
# [2020-07-27 14:47:53,326] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Found 19 stations (57 channels).
# [2020-07-27 14:47:53,331] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Will attempt to download data from 19 stations.
# [2020-07-27 14:47:53,335] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 57 time intervals/channels before downloading: NEEDS_DOWNLOADING
# [2020-07-27 14:47:53,992] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded 7 channels (of 7)
# [2020-07-27 14:47:54,341] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded 44 channels (of 50)
# [2020-07-27 14:47:54,342] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Launching basic QC checks...
# [2020-07-27 14:47:54,390] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Downloaded 0.3 MB [318.79 KB/sec] of data, 0.0 MB of which were discarded afterwards.
# [2020-07-27 14:47:54,391] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 6 time intervals/channels after downloading: DOWNLOAD_FAILED
# [2020-07-27 14:47:54,392] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 51 time intervals/channels after downloading: DOWNLOADED
# [2020-07-27 14:47:54,412] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - No station information to download.
# [2020-07-27 14:47:54,413] - obspy.clients.fdsn.mass_downloader - INFO: ============================== Final report
# [2020-07-27 14:47:54,413] - obspy.clients.fdsn.mass_downloader - INFO: 0 MiniSEED files [0.0 MB] already existed.
# [2020-07-27 14:47:54,414] - obspy.clients.fdsn.mass_downloader - INFO: 17 StationXML files [0.4 MB] already existed.
# [2020-07-27 14:47:54,415] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 51 MiniSEED files [0.3 MB].
# [2020-07-27 14:47:54,416] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 0 StationXML files [0.0 MB].
# [2020-07-27 14:47:54,416] - obspy.clients.fdsn.mass_downloader - INFO: Downloaded 0.3 MB in total.
# [2020-07-27 14:47:54,568] - obspy.clients.fdsn.mass_downloader - INFO: Initializing FDSN client(s) for http://service.iris.edu.
# [2020-07-27 14:47:54,570] - obspy.clients.fdsn.mass_downloader - INFO: Successfully initialized 1 client(s): http://service.iris.edu.
# [2020-07-27 14:47:54,571] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 0
# [2020-07-27 14:47:54,571] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Requesting reliable availability.
# [2020-07-27 14:47:57,231] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully requested availability (2.66 seconds)
# [2020-07-27 14:47:57,273] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Found 19 stations (57 channels).
# [2020-07-27 14:47:57,278] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Will attempt to download data from 19 stations.
# [2020-07-27 14:47:57,281] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 57 time intervals/channels before downloading: NEEDS_DOWNLOADING
# [2020-07-27 14:47:58,059] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded 7 channels (of 7)
# [2020-07-27 14:47:58,785] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded 41 channels (of 50)
# [2020-07-27 14:47:58,786] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Launching basic QC checks...
# [2020-07-27 14:47:58,828] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Downloaded 0.3 MB [209.82 KB/sec] of data, 0.0 MB of which were discarded afterwards.
# [2020-07-27 14:47:58,829] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 9 time intervals/channels after downloading: DOWNLOAD_FAILED
# [2020-07-27 14:47:58,830] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 48 time intervals/channels after downloading: DOWNLOADED
# [2020-07-27 14:47:58,849] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - No station information to download.
# [2020-07-27 14:47:58,849] - obspy.clients.fdsn.mass_downloader - INFO: ============================== Final report
# [2020-07-27 14:47:58,850] - obspy.clients.fdsn.mass_downloader - INFO: 0 MiniSEED files [0.0 MB] already existed.
# [2020-07-27 14:47:58,851] - obspy.clients.fdsn.mass_downloader - INFO: 16 StationXML files [0.4 MB] already existed.
# [2020-07-27 14:47:58,852] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 48 MiniSEED files [0.3 MB].
# [2020-07-27 14:47:58,852] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 0 StationXML files [0.0 MB].
# [2020-07-27 14:47:58,853] - obspy.clients.fdsn.mass_downloader - INFO: Downloaded 0.3 MB in total.
# finished downloading waveform data for crandall_test
# downloading station data for crandall_test dataset ...
# [2020-07-27 14:48:00,251] - obspy.clients.fdsn.mass_downloader - INFO: Initializing FDSN client(s) for http://service.iris.edu.
# [2020-07-27 14:48:00,253] - obspy.clients.fdsn.mass_downloader - INFO: Successfully initialized 1 client(s): http://service.iris.edu.
# [2020-07-27 14:48:00,254] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 0
# [2020-07-27 14:48:00,255] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Requesting reliable availability.
# [2020-07-27 14:48:02,064] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully requested availability (1.81 seconds)
# [2020-07-27 14:48:02,108] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Found 19 stations (57 channels).
# [2020-07-27 14:48:02,114] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Will attempt to download data from 19 stations.
# [2020-07-27 14:48:02,117] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 48 time intervals/channels before downloading: EXISTS
# [2020-07-27 14:48:02,118] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 9 time intervals/channels before downloading: NEEDS_DOWNLOADING
# [2020-07-27 14:48:02,558] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - No data available for request.
# [2020-07-27 14:48:02,559] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Launching basic QC checks...
# [2020-07-27 14:48:02,560] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Downloaded 0.0 MB [0.00 KB/sec] of data, 0.0 MB of which were discarded afterwards.
# [2020-07-27 14:48:02,561] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 9 time intervals/channels after downloading: DOWNLOAD_FAILED
# [2020-07-27 14:48:02,562] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 48 time intervals/channels after downloading: EXISTS
# [2020-07-27 14:48:02,581] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - No station information to download.
# [2020-07-27 14:48:02,581] - obspy.clients.fdsn.mass_downloader - INFO: ============================== Final report
# [2020-07-27 14:48:02,582] - obspy.clients.fdsn.mass_downloader - INFO: 48 MiniSEED files [0.4 MB] already existed.
# [2020-07-27 14:48:02,583] - obspy.clients.fdsn.mass_downloader - INFO: 16 StationXML files [0.4 MB] already existed.
# [2020-07-27 14:48:02,584] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 0 MiniSEED files [0.0 MB].
# [2020-07-27 14:48:02,584] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 0 StationXML files [0.0 MB].
# [2020-07-27 14:48:02,584] - obspy.clients.fdsn.mass_downloader - INFO: Downloaded 0.0 MB in total.
# [2020-07-27 14:48:02,666] - obspy.clients.fdsn.mass_downloader - INFO: Initializing FDSN client(s) for http://service.iris.edu.
# [2020-07-27 14:48:02,668] - obspy.clients.fdsn.mass_downloader - INFO: Successfully initialized 1 client(s): http://service.iris.edu.
# [2020-07-27 14:48:02,669] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 0
# [2020-07-27 14:48:02,669] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Requesting reliable availability.
# [2020-07-27 14:48:05,419] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully requested availability (2.75 seconds)
# [2020-07-27 14:48:05,469] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Found 19 stations (57 channels).
# [2020-07-27 14:48:05,475] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Will attempt to download data from 19 stations.
# [2020-07-27 14:48:05,478] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 51 time intervals/channels before downloading: EXISTS
# [2020-07-27 14:48:05,478] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 6 time intervals/channels before downloading: NEEDS_DOWNLOADING
# [2020-07-27 14:48:05,919] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - No data available for request.
# [2020-07-27 14:48:05,921] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Launching basic QC checks...
# [2020-07-27 14:48:05,922] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Downloaded 0.0 MB [0.00 KB/sec] of data, 0.0 MB of which were discarded afterwards.
# [2020-07-27 14:48:05,922] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 6 time intervals/channels after downloading: DOWNLOAD_FAILED
# [2020-07-27 14:48:05,923] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 51 time intervals/channels after downloading: EXISTS
# [2020-07-27 14:48:05,945] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - No station information to download.
# [2020-07-27 14:48:05,946] - obspy.clients.fdsn.mass_downloader - INFO: ============================== Final report
# [2020-07-27 14:48:05,948] - obspy.clients.fdsn.mass_downloader - INFO: 51 MiniSEED files [0.3 MB] already existed.
# [2020-07-27 14:48:05,948] - obspy.clients.fdsn.mass_downloader - INFO: 17 StationXML files [0.4 MB] already existed.
# [2020-07-27 14:48:05,949] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 0 MiniSEED files [0.0 MB].
# [2020-07-27 14:48:05,950] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 0 StationXML files [0.0 MB].
# [2020-07-27 14:48:05,951] - obspy.clients.fdsn.mass_downloader - INFO: Downloaded 0.0 MB in total.
# [2020-07-27 14:48:06,026] - obspy.clients.fdsn.mass_downloader - INFO: Initializing FDSN client(s) for http://service.iris.edu.
# [2020-07-27 14:48:06,028] - obspy.clients.fdsn.mass_downloader - INFO: Successfully initialized 1 client(s): http://service.iris.edu.
# [2020-07-27 14:48:06,028] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 0
# [2020-07-27 14:48:06,029] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Requesting reliable availability.
# [2020-07-27 14:48:08,242] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully requested availability (2.21 seconds)
# [2020-07-27 14:48:08,295] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Found 19 stations (57 channels).
# [2020-07-27 14:48:08,300] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Will attempt to download data from 19 stations.
# [2020-07-27 14:48:08,303] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 51 time intervals/channels before downloading: EXISTS
# [2020-07-27 14:48:08,303] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 6 time intervals/channels before downloading: NEEDS_DOWNLOADING
# [2020-07-27 14:48:08,794] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - No data available for request.
# [2020-07-27 14:48:08,796] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Launching basic QC checks...
# [2020-07-27 14:48:08,797] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Downloaded 0.0 MB [0.00 KB/sec] of data, 0.0 MB of which were discarded afterwards.
# [2020-07-27 14:48:08,798] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 6 time intervals/channels after downloading: DOWNLOAD_FAILED
# [2020-07-27 14:48:08,798] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 51 time intervals/channels after downloading: EXISTS
# [2020-07-27 14:48:08,820] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - No station information to download.
# [2020-07-27 14:48:08,820] - obspy.clients.fdsn.mass_downloader - INFO: ============================== Final report
# [2020-07-27 14:48:08,821] - obspy.clients.fdsn.mass_downloader - INFO: 51 MiniSEED files [0.3 MB] already existed.
# [2020-07-27 14:48:08,822] - obspy.clients.fdsn.mass_downloader - INFO: 17 StationXML files [0.4 MB] already existed.
# [2020-07-27 14:48:08,823] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 0 MiniSEED files [0.0 MB].
# [2020-07-27 14:48:08,823] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 0 StationXML files [0.0 MB].
# [2020-07-27 14:48:08,824] - obspy.clients.fdsn.mass_downloader - INFO: Downloaded 0.0 MB in total.
# [2020-07-27 14:48:08,892] - obspy.clients.fdsn.mass_downloader - INFO: Initializing FDSN client(s) for http://service.iris.edu.
# [2020-07-27 14:48:08,895] - obspy.clients.fdsn.mass_downloader - INFO: Successfully initialized 1 client(s): http://service.iris.edu.
# [2020-07-27 14:48:08,895] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 0
# [2020-07-27 14:48:08,896] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Requesting reliable availability.
# [2020-07-27 14:48:11,118] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully requested availability (2.22 seconds)
# [2020-07-27 14:48:11,164] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Found 19 stations (57 channels).
# [2020-07-27 14:48:11,169] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Will attempt to download data from 19 stations.
# [2020-07-27 14:48:11,173] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 51 time intervals/channels before downloading: EXISTS
# [2020-07-27 14:48:11,173] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 6 time intervals/channels before downloading: NEEDS_DOWNLOADING
# [2020-07-27 14:48:11,622] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - No data available for request.
# [2020-07-27 14:48:11,624] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Launching basic QC checks...
# [2020-07-27 14:48:11,625] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Downloaded 0.0 MB [0.00 KB/sec] of data, 0.0 MB of which were discarded afterwards.
# [2020-07-27 14:48:11,625] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 6 time intervals/channels after downloading: DOWNLOAD_FAILED
# [2020-07-27 14:48:11,626] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 51 time intervals/channels after downloading: EXISTS
# [2020-07-27 14:48:11,649] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - No station information to download.
# [2020-07-27 14:48:11,650] - obspy.clients.fdsn.mass_downloader - INFO: ============================== Final report
# [2020-07-27 14:48:11,651] - obspy.clients.fdsn.mass_downloader - INFO: 51 MiniSEED files [0.3 MB] already existed.
# [2020-07-27 14:48:11,651] - obspy.clients.fdsn.mass_downloader - INFO: 17 StationXML files [0.4 MB] already existed.
# [2020-07-27 14:48:11,652] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 0 MiniSEED files [0.0 MB].
# [2020-07-27 14:48:11,652] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 0 StationXML files [0.0 MB].
# [2020-07-27 14:48:11,653] - obspy.clients.fdsn.mass_downloader - INFO: Downloaded 0.0 MB in total.
# [2020-07-27 14:48:11,723] - obspy.clients.fdsn.mass_downloader - INFO: Initializing FDSN client(s) for http://service.iris.edu.
# [2020-07-27 14:48:11,724] - obspy.clients.fdsn.mass_downloader - INFO: Successfully initialized 1 client(s): http://service.iris.edu.
# [2020-07-27 14:48:11,725] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 0
# [2020-07-27 14:48:11,725] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Requesting reliable availability.
# [2020-07-27 14:48:14,189] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully requested availability (2.46 seconds)
# [2020-07-27 14:48:14,233] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Found 19 stations (57 channels).
# [2020-07-27 14:48:14,238] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Will attempt to download data from 19 stations.
# [2020-07-27 14:48:14,241] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 51 time intervals/channels before downloading: EXISTS
# [2020-07-27 14:48:14,241] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 6 time intervals/channels before downloading: NEEDS_DOWNLOADING
# [2020-07-27 14:48:14,681] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - No data available for request.
# [2020-07-27 14:48:14,683] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Launching basic QC checks...
# [2020-07-27 14:48:14,684] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Downloaded 0.0 MB [0.00 KB/sec] of data, 0.0 MB of which were discarded afterwards.
# [2020-07-27 14:48:14,685] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 6 time intervals/channels after downloading: DOWNLOAD_FAILED
# [2020-07-27 14:48:14,686] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 51 time intervals/channels after downloading: EXISTS
# [2020-07-27 14:48:14,706] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - No station information to download.
# [2020-07-27 14:48:14,706] - obspy.clients.fdsn.mass_downloader - INFO: ============================== Final report
# [2020-07-27 14:48:14,707] - obspy.clients.fdsn.mass_downloader - INFO: 51 MiniSEED files [0.3 MB] already existed.
# [2020-07-27 14:48:14,708] - obspy.clients.fdsn.mass_downloader - INFO: 17 StationXML files [0.4 MB] already existed.
# [2020-07-27 14:48:14,708] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 0 MiniSEED files [0.0 MB].
# [2020-07-27 14:48:14,709] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 0 StationXML files [0.0 MB].
# [2020-07-27 14:48:14,709] - obspy.clients.fdsn.mass_downloader - INFO: Downloaded 0.0 MB in total.
# [2020-07-27 14:48:14,784] - obspy.clients.fdsn.mass_downloader - INFO: Initializing FDSN client(s) for http://service.iris.edu.
# [2020-07-27 14:48:14,786] - obspy.clients.fdsn.mass_downloader - INFO: Successfully initialized 1 client(s): http://service.iris.edu.
# [2020-07-27 14:48:14,786] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 0
# [2020-07-27 14:48:14,787] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Requesting reliable availability.
# [2020-07-27 14:48:16,905] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully requested availability (2.12 seconds)
# [2020-07-27 14:48:16,951] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Found 19 stations (57 channels).
# [2020-07-27 14:48:16,955] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Will attempt to download data from 19 stations.
# [2020-07-27 14:48:16,958] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 48 time intervals/channels before downloading: EXISTS
# [2020-07-27 14:48:16,959] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 9 time intervals/channels before downloading: NEEDS_DOWNLOADING
# [2020-07-27 14:48:17,393] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - No data available for request.
# [2020-07-27 14:48:17,394] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Launching basic QC checks...
# [2020-07-27 14:48:17,395] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Downloaded 0.0 MB [0.00 KB/sec] of data, 0.0 MB of which were discarded afterwards.
# [2020-07-27 14:48:17,396] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 9 time intervals/channels after downloading: DOWNLOAD_FAILED
# [2020-07-27 14:48:17,397] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 48 time intervals/channels after downloading: EXISTS
# [2020-07-27 14:48:17,418] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - No station information to download.
# [2020-07-27 14:48:17,418] - obspy.clients.fdsn.mass_downloader - INFO: ============================== Final report
# [2020-07-27 14:48:17,419] - obspy.clients.fdsn.mass_downloader - INFO: 48 MiniSEED files [0.3 MB] already existed.
# [2020-07-27 14:48:17,420] - obspy.clients.fdsn.mass_downloader - INFO: 16 StationXML files [0.4 MB] already existed.
# [2020-07-27 14:48:17,420] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 0 MiniSEED files [0.0 MB].
# [2020-07-27 14:48:17,420] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 0 StationXML files [0.0 MB].
# [2020-07-27 14:48:17,421] - obspy.clients.fdsn.mass_downloader - INFO: Downloaded 0.0 MB in total.
# [2020-07-27 14:48:17,490] - obspy.clients.fdsn.mass_downloader - INFO: Initializing FDSN client(s) for http://service.iris.edu.
# [2020-07-27 14:48:17,491] - obspy.clients.fdsn.mass_downloader - INFO: Successfully initialized 1 client(s): http://service.iris.edu.
# [2020-07-27 14:48:17,492] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 0
# [2020-07-27 14:48:17,493] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Requesting reliable availability.
# [2020-07-27 14:48:19,688] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully requested availability (2.19 seconds)
# [2020-07-27 14:48:19,731] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Found 19 stations (57 channels).
# [2020-07-27 14:48:19,736] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Will attempt to download data from 19 stations.
# [2020-07-27 14:48:19,738] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 51 time intervals/channels before downloading: EXISTS
# [2020-07-27 14:48:19,739] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 6 time intervals/channels before downloading: NEEDS_DOWNLOADING
# [2020-07-27 14:48:20,179] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - No data available for request.
# [2020-07-27 14:48:20,181] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Launching basic QC checks...
# [2020-07-27 14:48:20,182] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Downloaded 0.0 MB [0.00 KB/sec] of data, 0.0 MB of which were discarded afterwards.
# [2020-07-27 14:48:20,183] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 6 time intervals/channels after downloading: DOWNLOAD_FAILED
# [2020-07-27 14:48:20,184] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 51 time intervals/channels after downloading: EXISTS
# [2020-07-27 14:48:20,205] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - No station information to download.
# [2020-07-27 14:48:20,205] - obspy.clients.fdsn.mass_downloader - INFO: ============================== Final report
# [2020-07-27 14:48:20,206] - obspy.clients.fdsn.mass_downloader - INFO: 51 MiniSEED files [0.3 MB] already existed.
# [2020-07-27 14:48:20,207] - obspy.clients.fdsn.mass_downloader - INFO: 17 StationXML files [0.4 MB] already existed.
# [2020-07-27 14:48:20,207] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 0 MiniSEED files [0.0 MB].
# [2020-07-27 14:48:20,208] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 0 StationXML files [0.0 MB].
# [2020-07-27 14:48:20,208] - obspy.clients.fdsn.mass_downloader - INFO: Downloaded 0.0 MB in total.
# [2020-07-27 14:48:20,282] - obspy.clients.fdsn.mass_downloader - INFO: Initializing FDSN client(s) for http://service.iris.edu.
# [2020-07-27 14:48:20,284] - obspy.clients.fdsn.mass_downloader - INFO: Successfully initialized 1 client(s): http://service.iris.edu.
# [2020-07-27 14:48:20,284] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 0
# [2020-07-27 14:48:20,284] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Requesting reliable availability.
# [2020-07-27 14:48:22,054] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully requested availability (1.77 seconds)
# [2020-07-27 14:48:22,106] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Found 19 stations (57 channels).
# [2020-07-27 14:48:22,112] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Will attempt to download data from 19 stations.
# [2020-07-27 14:48:22,114] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 48 time intervals/channels before downloading: EXISTS
# [2020-07-27 14:48:22,115] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 9 time intervals/channels before downloading: NEEDS_DOWNLOADING
# [2020-07-27 14:48:22,872] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - No data available for request.
# [2020-07-27 14:48:22,873] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Launching basic QC checks...
# [2020-07-27 14:48:22,875] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Downloaded 0.0 MB [0.00 KB/sec] of data, 0.0 MB of which were discarded afterwards.
# [2020-07-27 14:48:22,876] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 9 time intervals/channels after downloading: DOWNLOAD_FAILED
# [2020-07-27 14:48:22,877] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 48 time intervals/channels after downloading: EXISTS
# [2020-07-27 14:48:22,896] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - No station information to download.
# [2020-07-27 14:48:22,897] - obspy.clients.fdsn.mass_downloader - INFO: ============================== Final report
# [2020-07-27 14:48:22,898] - obspy.clients.fdsn.mass_downloader - INFO: 48 MiniSEED files [0.3 MB] already existed.
# [2020-07-27 14:48:22,898] - obspy.clients.fdsn.mass_downloader - INFO: 16 StationXML files [0.4 MB] already existed.
# [2020-07-27 14:48:22,899] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 0 MiniSEED files [0.0 MB].
# [2020-07-27 14:48:22,899] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 0 StationXML files [0.0 MB].
# [2020-07-27 14:48:22,899] - obspy.clients.fdsn.mass_downloader - INFO: Downloaded 0.0 MB in total.
# finished downloading station data for crandall_test
# downloading event data for crandall_test dataset ...
# finished downloading event data for crandall_test

# %% [markdown]
# Likewise, the Fetcher can be initialized with any objects from which the appropriate client can be obtained. Commonly it is used with a `WaveBank`, a `Catalog` (or `EventBank`) and an `Inventory`. The following would also be valid:

# %%
cat = crandall.event_client.get_events()
inv = crandall.station_client.get_stations()
wavebank = crandall.waveform_client

crandall_fetcher = obsplus.Fetcher(waveforms=wavebank, stations=inv, events=cat)

# %% [markdown]
# The WaveFetcher constructor can also take obsplus created csv/dataframes for the [stations](../datastructures/stations_to_pandas.ipynb) and [events](../datastructures/events_to_pandas.ipynb) arguments. However, this may limit some of its uses.

# %% [markdown]
# ## Quick fetch
# The easiest way to get data out of a data fetcher is to call it. The fetcher takes an argument that will provide it with information about when the stream should start. It can be a variety of types (float, UTCDateTime, Catalog, Event). The time before the reference time, and the time after the reference time must also be provided in the method call or in the `Fetcher` construction.
#
# The fetcher uses the inventory (or `station_client`) to know which channels to request from the waveform_client.

# %%
import obspy
reference_time = obspy.UTCDateTime('2007-02-15T06')
time_before = 1
time_after = 30
stream = ta_fetcher(reference_time, time_before, time_after)
print(stream)
# Out:
# 6 Trace(s) in Stream:
# TA.M11A..VHE | 2007-02-15T05:59:59.999998Z - 2007-02-15T06:00:29.999998Z | 0.1 Hz, 4 samples
# TA.M11A..VHN | 2007-02-15T05:59:59.999998Z - 2007-02-15T06:00:29.999998Z | 0.1 Hz, 4 samples
# TA.M11A..VHZ | 2007-02-15T05:59:59.999998Z - 2007-02-15T06:00:29.999998Z | 0.1 Hz, 4 samples
# TA.M14A..VHE | 2007-02-15T06:00:00.000003Z - 2007-02-15T06:00:30.000003Z | 0.1 Hz, 4 samples
# TA.M14A..VHN | 2007-02-15T06:00:00.000003Z - 2007-02-15T06:00:30.000003Z | 0.1 Hz, 4 samples
# TA.M14A..VHZ | 2007-02-15T06:00:00.000004Z - 2007-02-15T06:00:30.000004Z | 0.1 Hz, 4 samples

# %% [markdown]
# ## Continuous data
#
# Continuous data can be requested from the wavefetcher, which uses the `station_client` to know which channels to pull from the waveform_client. This enables users to skip a lot of the boiler-plate associated with the normal `get_waveforms` interface.
#
# For example, looping over all the continuous data and and running a simple STA/LTA detector could be done like so:

# %%
from obspy.signal.trigger import classic_sta_lta

# first define a function for doing the sta/lta
def print_sta_lta(tr: obspy.Trace):
    """ prints the sta/lta """
    sr = tr.stats.sampling_rate
    cft = classic_sta_lta(tr.data, int(20 * sr), int(60 * sr))
    print(f'{tr.id} starting at {st[0].stats.starttime}, has a max sta/lta of {max(cft):0.2f}')

# %%
# starttime for the continuous data
t1 = obspy.UTCDateTime('2007-02-16')

# endtime for the continuous data
t2 = t1 + 36000 * 10  # use 10 hours

# duration of each chunk returned (in seconds)
duration = 72000

# overlap (added to the end of the duration)
overlap = 60

# iterate over each chunk
kwargs = dict(starttime=t1, endtime=t2, duration=duration, overlap=overlap)
for st in ta_fetcher.yield_waveforms(**kwargs):
    # select only z component and perform preprocessing
    st = st.select(component='Z')
    st.detrend('linear')
    # do the sta/lta
    for tr in st:
        print_sta_lta(tr)
# Out:
# TA.M11A..VHZ starting at 2007-02-15T23:59:59.999998Z, has a max sta/lta of 2.88
# TA.M14A..VHZ starting at 2007-02-15T23:59:59.999998Z, has a max sta/lta of 2.98
# TA.M11A..VHZ starting at 2007-02-16T19:59:59.999998Z, has a max sta/lta of 2.98
# TA.M14A..VHZ starting at 2007-02-16T19:59:59.999998Z, has a max sta/lta of 2.97
# TA.M11A..VHZ starting at 2007-02-17T15:59:59.999998Z, has a max sta/lta of 2.95
# TA.M14A..VHZ starting at 2007-02-17T15:59:59.999998Z, has a max sta/lta of 2.84
# TA.M11A..VHZ starting at 2007-02-18T11:59:59.999998Z, has a max sta/lta of 2.98
# TA.M14A..VHZ starting at 2007-02-18T11:59:59.999998Z, has a max sta/lta of 3.00
# TA.M11A..VHZ starting at 2007-02-19T07:59:59.999998Z, has a max sta/lta of 2.93
# TA.M14A..VHZ starting at 2007-02-19T07:59:59.999998Z, has a max sta/lta of 2.93

# %% [markdown]
# ## Stream processors
#
# It can be useful to define a stream_processing function that will be called on each stream before yielding it. This allows users to define flexible, custom processing functions without cluttering up the function calls with a lot of processing parameters.

# %%
# define a function that will be called on the stream before returning it. 
def stream_processor(st: obspy.Stream) -> obspy.Stream:
    """ select the z component, detrend, and filter a stream """
    st = st.select(component='Z')
    st.detrend('linear')
    st.filter('bandpass', freqmin=.005, freqmax=.04)
    return st

# attach stream processor to the wave fetcher
ta_fetcher.stream_processor = stream_processor

kwargs = dict(starttime=t1, endtime=t2, duration=duration, overlap=overlap)
for st in ta_fetcher.yield_waveforms(**kwargs):
    for tr in st:
        print_sta_lta(tr)
# Out:
# TA.M11A..VHZ starting at 2007-02-15T23:59:59.999998Z, has a max sta/lta of 2.96
# TA.M14A..VHZ starting at 2007-02-15T23:59:59.999998Z, has a max sta/lta of 2.95
# TA.M11A..VHZ starting at 2007-02-16T19:59:59.999998Z, has a max sta/lta of 2.95
# TA.M14A..VHZ starting at 2007-02-16T19:59:59.999998Z, has a max sta/lta of 3.00
# TA.M11A..VHZ starting at 2007-02-17T15:59:59.999998Z, has a max sta/lta of 2.98
# TA.M14A..VHZ starting at 2007-02-17T15:59:59.999998Z, has a max sta/lta of 2.96
# TA.M11A..VHZ starting at 2007-02-18T11:59:59.999998Z, has a max sta/lta of 2.99
# TA.M14A..VHZ starting at 2007-02-18T11:59:59.999998Z, has a max sta/lta of 2.97
# TA.M11A..VHZ starting at 2007-02-19T07:59:59.999998Z, has a max sta/lta of 3.00
# TA.M14A..VHZ starting at 2007-02-19T07:59:59.999998Z, has a max sta/lta of 2.99

# %% [markdown]
# ## Event data
#
# Because we provided the wavefetcher object with an event client, we can use it to iterate through the event waveforms.

# %%
time_before = 1
time_after = 3
iterrator = crandall_fetcher.yield_event_waveforms(time_before, time_after)
for event_id, st in iterrator:
    print(f'fetched waveform data for {event_id} which has {len(st)} traces')
# Out:
# fetched waveform data for smi:local/248828 which has 48 traces
# fetched waveform data for smi:local/248839 which has 48 traces
# fetched waveform data for smi:local/248843 which has 48 traces
# fetched waveform data for smi:local/248882 which has 51 traces
# fetched waveform data for smi:local/248883 which has 51 traces
# fetched waveform data for smi:local/248887 which has 51 traces
# fetched waveform data for smi:local/248891 which has 51 traces
# fetched waveform data for smi:local/248925 which has 51 traces

# %% [markdown]
# We can also create a dict of {event_id: stream}.

# %%
st_dict = dict(crandall_fetcher.yield_event_waveforms(time_before, time_after))

for event_id, st in st_dict.items():
    print(event_id, len(st))
# Out:
# smi:local/248828 48
# smi:local/248839 48
# smi:local/248843 48
# smi:local/248882 51
# smi:local/248883 51
# smi:local/248887 51
# smi:local/248891 51
# smi:local/248925 51

# %% [markdown]
# ## Different events/inventories
# The clients can be swapped out on each method call. This may be be useful to get a subset of the events or channels by providing a filtered catalog/inventory. For example, if we were only interested in Station M11A for a single call (but didn't want to modify the original wavefetcher) this could be easily accomplished like so:

# %%
# get a subset of the original inventory ()
inv = ta_dataset.station_client.get_stations()
inv2 = inv.select(station='M11A')

# iterate and print
for st in ta_fetcher.yield_waveforms(t1, t2, duration, overlap, stations=inv2):
    for tr in st:
        print_sta_lta(tr)

# %% [markdown]
# The same applies for swapping out events:

# %%
# read in catalog as and get a subset as a dataframe
cat = crandall.event_client.get_events()
cat_df = obsplus.events_to_df(cat)[:2]

# iterate the events and print 
iterator = crandall_fetcher.yield_event_waveforms(time_before, time_after, events=cat_df)
for event_id, st in iterator:
    print(f'fetching {event_id}, got {len(st)} traces')
# Out:
# fetching smi:local/248839, got 48 traces
# fetching smi:local/248883, got 51 traces
